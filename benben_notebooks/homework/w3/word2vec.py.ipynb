# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    print(statinfo.st_size)
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# 31344016

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5235, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels
print('index:', data[:8])
print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# index: [5235, 3081, 12, 6, 195, 2, 3134, 46]
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'of', 'as', 'originated', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step %d: %f' % (step, average_loss))
                average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Nearest to nine: seeded, whitman, piles, beatmatching, synonym, fretboard, originate, forests,
# Nearest to not: djs, bahasa, plaintexts, strikingly, bureaucrats, microtonal, addict, demonic,
# Nearest to they: audition, tabari, accident, bibliographical, redistricting, prepares, adjacency, belonging,
# Nearest to some: lbs, muscat, deduced, fulk, despot, plaintiffs, fuss, rcs,
# Nearest to first: tres, irishman, hanlon, bushy, inaugural, pellets, picket, squeezing,
# Nearest to s: woolf, cnn, cesium, iran, contemplate, cites, osiris, kinetochores,
# Nearest to these: tg, breda, adding, whitaker, handwriting, secreted, exhibitions, hour,
# Nearest to other: gcl, correspondences, lackluster, stripper, barium, dorians, airspeed, paragon,
# Nearest to but: amiable, drew, occultation, bolder, fillmore, fanny, failing, heartfelt,
# Nearest to there: grumman, slugs, locksmiths, albertosaurus, card, zuse, flourishing, unstressed,
# Nearest to use: condita, floor, anastasius, places, lobe, kekkonen, anywhere, crushes,
# Nearest to is: construct, krag, triumphs, quartier, astute, dkw, isabelle, lusitanian,
# Nearest to he: gangster, mirc, linspire, walkie, substance, fouled, weighed, kekkonen,
# Nearest to also: incantations, admissible, phyla, enzymatic, preparations, bethune, cleared, swapped,
# Nearest to UNK: osteoarthritis, plenary, supers, raced, koufax, impress, northeast, loya,
# Nearest to th: signatories, teosinte, revisions, pointy, diss, navies, caribou, communication,
# Average loss at step 2000: 4.372447
# Average loss at step 4000: 3.862948
# Average loss at step 6000: 3.782332
# Average loss at step 8000: 3.684361
# Average loss at step 10000: 3.616420
# Nearest to nine: eight, six, five, seven, zero, four, three, two,
# Nearest to not: buoyancy, it, southey, refusing, sometimes, to, who, still,
# Nearest to they: he, there, it, audition, we, actually, bizarre, tabari,
# Nearest to some: lbs, many, distaste, macau, cellists, sinan, gide, fixes,
# Nearest to first: during, sounding, muskets, notoriety, omissions, pickup, authenticity, scientists,
# Nearest to s: his, and, dinosaurs, nathanael, ordinances, osiris, nurse, berets,
# Nearest to these: whitaker, cues, handwriting, filters, sophistication, analgesic, armenian, breda,
# Nearest to other: mistletoe, correspondences, jacopo, transitivity, tammany, epa, forks, yugoslav,
# Nearest to but: amiable, unsurpassed, serie, fingertips, occultation, often, magistrates, arno,
# Nearest to there: it, vindicated, they, grumman, he, card, commonly, no,
# Nearest to use: floor, condita, starboard, places, anastasius, lobe, anywhere, knebworth,
# Nearest to is: was, are, has, be, deoxyribose, synthesis, witches, polg,
# Nearest to he: it, they, she, who, there, gangster, callers, vests,
# Nearest to also: incantations, who, often, it, which, gmt, enzymatic, uprising,
# Nearest to UNK: isca, m, tienne, millicent, interior, donate, oyster, fleurs,
# Nearest to th: four, six, five, seven, abdel, signatories, three, eight,
# Average loss at step 12000: 3.599640
# Average loss at step 14000: 3.573257
# Average loss at step 16000: 3.406943
# Average loss at step 18000: 3.455050
# Average loss at step 20000: 3.538924
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to not: also, still, to, it, they, you, never, illusory,
# Nearest to they: he, there, we, it, actually, who, audition, not,
# Nearest to some: many, several, these, lbs, all, distaste, gide, most,
# Nearest to first: last, asks, nunnery, during, notoriety, timorese, muskets, elemental,
# Nearest to s: dinosaurs, banaba, empty, hong, nathanael, avenging, registration, eradicating,
# Nearest to these: some, such, many, whitaker, which, other, all, analgesic,
# Nearest to other: many, various, some, epa, these, different, xxxx, jacopo,
# Nearest to but: however, that, which, although, if, is, and, amiable,
# Nearest to there: it, they, vindicated, he, which, also, grumman, we,
# Nearest to use: floor, places, starboard, multimedia, anastasius, condita, rota, queues,
# Nearest to is: was, are, has, be, but, does, were, monet,
# Nearest to he: it, they, she, who, there, gangster, which, callers,
# Nearest to also: often, which, now, not, who, there, sometimes, commonly,
# Nearest to UNK: tarkovsky, millicent, whore, quizzes, briefing, trinitarians, piqad, zombie,
# Nearest to th: survivor, abdel, keith, tribunal, ethiopia, literal, gringo, signatories,
# Average loss at step 22000: 3.504375
# Average loss at step 24000: 3.493775
# Average loss at step 26000: 3.479393
# Average loss at step 28000: 3.476286
# Average loss at step 30000: 3.504965
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to not: still, they, it, to, never, often, there, sometimes,
# Nearest to they: there, we, he, it, these, you, who, not,
# Nearest to some: many, these, several, all, other, most, distaste, their,
# Nearest to first: last, second, asks, sounding, next, fourth, nunnery, during,
# Nearest to s: his, and, clancy, alluvial, tyson, combinatory, autographs, ira,
# Nearest to these: some, many, they, which, such, there, their, several,
# Nearest to other: some, various, foote, different, these, others, such, many,
# Nearest to but: however, although, which, and, that, see, if, fc,
# Nearest to there: they, it, vindicated, he, we, ferrand, often, these,
# Nearest to use: floor, multimedia, starboard, rota, multiply, drying, competitors, places,
# Nearest to is: was, has, are, became, corsica, be, viipuri, does,
# Nearest to he: she, it, they, who, there, callers, gangster, deserted,
# Nearest to also: often, now, which, already, it, who, still, usually,
# Nearest to UNK: molars, tienne, krahn, pigment, innocent, e, sef, allosteric,
# Nearest to th: six, eight, nd, bc, survivor, abdel, rd, signatories,
# Average loss at step 32000: 3.500967
# Average loss at step 34000: 3.499200
# Average loss at step 36000: 3.454995
# Average loss at step 38000: 3.301391
# Average loss at step 40000: 3.423327
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to not: still, never, they, it, also, often, to, t,
# Nearest to they: we, he, there, you, it, these, she, not,
# Nearest to some: many, these, several, any, this, distaste, most, the,
# Nearest to first: last, second, next, during, nunnery, fourth, omissions, asks,
# Nearest to s: his, humourous, infringes, virginals, her, brazzaville, alluvial, specifics,
# Nearest to these: some, many, they, several, such, including, which, lola,
# Nearest to other: different, various, some, multics, attractions, digraphs, others, workgroups,
# Nearest to but: however, although, and, are, while, which, it, he,
# Nearest to there: it, they, vindicated, he, often, she, usually, now,
# Nearest to use: form, eleusinian, starboard, floor, multiply, nun, kh, outages,
# Nearest to is: was, are, be, if, has, does, embraces, became,
# Nearest to he: she, it, they, who, there, eventually, but, i,
# Nearest to also: often, which, still, now, usually, disinfectant, not, sometimes,
# Nearest to UNK: b, d, composers, swing, stenella, athlete, politician, eyed,
# Nearest to th: bc, nd, survivor, rd, abdel, deptford, locality, literal,
# Average loss at step 42000: 3.434182
# Average loss at step 44000: 3.452161
# Average loss at step 46000: 3.449214
# Average loss at step 48000: 3.353421
# Average loss at step 50000: 3.385939
# Nearest to nine: eight, six, seven, four, three, five, zero, two,
# Nearest to not: never, still, they, it, now, generally, always, microtonal,
# Nearest to they: we, there, he, you, these, it, she, who,
# Nearest to some: many, several, these, their, bombay, most, the, various,
# Nearest to first: second, last, nunnery, next, under, incandescent, afternoon, nomads,
# Nearest to s: alluvial, whose, daisies, sad, while, charon, and, has,
# Nearest to these: some, many, several, both, they, such, are, lola,
# Nearest to other: various, different, many, monist, some, christian, tuvalu, linguistic,
# Nearest to but: however, although, while, and, though, when, which, integrating,
# Nearest to there: they, it, he, vindicated, she, now, we, ferrand,
# Nearest to use: multiply, form, queues, outages, turtle, amount, elbaradei, starboard,
# Nearest to is: was, has, are, became, contains, be, remains, seems,
# Nearest to he: she, it, they, who, there, this, eventually, callers,
# Nearest to also: often, which, still, now, here, sometimes, actually, then,
# Nearest to UNK: eyed, potemkin, millicent, avoidance, gymnast, molars, oval, e,
# Nearest to th: bc, six, five, rd, survivor, nineteenth, nd, four,
# Average loss at step 52000: 3.436953
# Average loss at step 54000: 3.423416
# Average loss at step 56000: 3.440326
# Average loss at step 58000: 3.397388
# Average loss at step 60000: 3.391187
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to not: still, never, usually, t, masoch, microtonal, they, permafrost,
# Nearest to they: we, there, he, you, she, these, it, reparations,
# Nearest to some: many, several, these, the, most, all, this, any,
# Nearest to first: second, last, next, odyssey, work, innocuous, third, nunnery,
# Nearest to s: alluvial, implausible, whose, slapped, hugh, his, empty, roth,
# Nearest to these: some, many, several, those, both, which, they, such,
# Nearest to other: different, various, many, others, several, longer, multics, expensive,
# Nearest to but: however, and, although, see, when, though, while, than,
# Nearest to there: it, they, now, she, this, he, ferrand, still,
# Nearest to use: form, sense, queues, multiply, templeton, consider, columns, outages,
# Nearest to is: was, are, has, although, contains, remains, be, if,
# Nearest to he: she, it, they, there, who, we, eventually, originally,
# Nearest to also: now, often, still, sometimes, usually, which, there, actually,
# Nearest to UNK: wikitravel, nonempty, volcanic, courtier, scarp, portfolios, whore, utraquists,
# Nearest to th: six, bc, five, nd, rd, eight, abdel, st,
# Average loss at step 62000: 3.243034
# Average loss at step 64000: 3.250526
# Average loss at step 66000: 3.400982
# Average loss at step 68000: 3.399359
# Average loss at step 70000: 3.357460
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to not: still, never, usually, now, also, masoch, resurface, generally,
# Nearest to they: we, he, there, you, she, it, reparations, these,
# Nearest to some: many, several, these, all, most, various, their, other,
# Nearest to first: second, last, next, third, fourth, innocuous, odyssey, final,
# Nearest to s: whose, dortmund, your, nathanael, leopold, flamboyant, autographs, alluvial,
# Nearest to these: some, many, such, several, are, those, various, which,
# Nearest to other: many, various, different, some, multics, others, imprison, like,
# Nearest to but: however, although, and, though, which, see, that, while,
# Nearest to there: they, it, still, we, vindicated, he, ferrand, she,
# Nearest to use: sense, consider, form, most, multiply, presence, terms, templeton,
# Nearest to is: was, has, are, be, although, became, makes, does,
# Nearest to he: she, it, they, there, who, eventually, we, originally,
# Nearest to also: now, still, often, which, usually, sometimes, not, there,
# Nearest to UNK: webelements, mond, factorizations, distro, blackface, corfu, info, gymnast,
# Nearest to th: bc, rd, nd, abdel, st, nineteenth, ad, graduate,
# Average loss at step 72000: 3.377719
# Average loss at step 74000: 3.345523
# Average loss at step 76000: 3.311741
# Average loss at step 78000: 3.352611
# Average loss at step 80000: 3.375453
# Nearest to nine: eight, seven, five, six, four, three, zero, two,
# Nearest to not: still, never, always, actually, usually, generally, we, ever,
# Nearest to they: we, he, there, she, you, it, these, spyware,
# Nearest to some: many, several, these, most, various, this, all, any,
# Nearest to first: second, last, third, next, innocuous, omissions, fourth, same,
# Nearest to s: judaica, arnold, edie, tainted, rtl, westinghouse, server, implausible,
# Nearest to these: many, both, some, those, several, such, various, are,
# Nearest to other: various, different, many, others, multics, linguistic, executable, neolithic,
# Nearest to but: however, although, while, and, though, which, he, they,
# Nearest to there: it, they, he, often, she, still, sometimes, we,
# Nearest to use: sense, consider, form, conscription, queues, criminality, because, miao,
# Nearest to is: was, has, became, are, although, be, remains, contains,
# Nearest to he: she, it, they, there, who, we, callers, eventually,
# Nearest to also: now, often, still, which, sometimes, usually, commonly, cayce,
# Nearest to UNK: webelements, jackson, serre, poet, gen, welt, ohrid, lee,
# Nearest to th: bc, rd, nd, graduate, abdel, four, five, survivor,
# Average loss at step 82000: 3.405706
# Average loss at step 84000: 3.409284
# Average loss at step 86000: 3.391875
# Average loss at step 88000: 3.355006
# Average loss at step 90000: 3.363543
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to not: still, actually, never, we, masoch, it, they, now,
# Nearest to they: we, he, there, she, you, it, but, these,
# Nearest to some: many, several, these, any, most, both, certain, all,
# Nearest to first: last, second, third, fourth, omissions, detainees, next, same,
# Nearest to s: isbn, his, whose, edie, rtl, einen, your, westinghouse,
# Nearest to these: several, many, some, both, are, those, such, various,
# Nearest to other: various, different, individual, many, specific, others, food, dreamed,
# Nearest to but: however, and, although, while, though, which, he, since,
# Nearest to there: they, it, he, we, still, she, often, sometimes,
# Nearest to use: most, consider, sense, list, support, because, contempt, queues,
# Nearest to is: was, has, are, although, makes, became, becomes, be,
# Nearest to he: she, they, it, there, who, finally, but, originally,
# Nearest to also: often, now, still, which, actually, sometimes, usually, crippling,
# Nearest to UNK: ornithologist, corfu, officer, anastasio, stanislaus, topless, magnets, gerard,
# Nearest to th: rd, bc, six, graduate, nd, one, bce, seven,
# Average loss at step 92000: 3.399036
# Average loss at step 94000: 3.254415
# Average loss at step 96000: 3.354050
# Average loss at step 98000: 3.245871
# Average loss at step 100000: 3.358111
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to not: still, never, actually, generally, always, they, now, already,
# Nearest to they: we, he, there, she, you, it, i, spyware,
# Nearest to some: many, several, these, any, various, numerous, all, most,
# Nearest to first: last, second, next, third, fourth, final, annexation, omissions,
# Nearest to s: his, whose, isbn, nathanael, carson, the, martina, rtl,
# Nearest to these: several, some, many, various, those, all, were, both,
# Nearest to other: various, others, individual, different, food, specific, dey, francorum,
# Nearest to but: however, although, and, though, while, which, that, when,
# Nearest to there: they, it, he, we, she, still, often, now,
# Nearest to use: sense, most, need, contempt, queues, form, elbaradei, support,
# Nearest to is: was, has, became, be, had, are, seems, becomes,
# Nearest to he: she, it, they, there, who, we, this, never,
# Nearest to also: now, actually, often, still, never, sometimes, which, generally,
# Nearest to UNK: es, igneous, duals, complicity, pinyin, ill, bickering, mistakenly,
# Nearest to th: rd, bc, nd, graduate, third, nineteenth, binet, hymnody,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
