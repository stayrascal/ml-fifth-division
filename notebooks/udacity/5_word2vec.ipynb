# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'
root_dir = '../data/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download(root_dir + 'text8.zip', 31344016)
# Out:
# Found and verified ../data/text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
        unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 17005207], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
    
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
    
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'term', 'of', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.824585
# Nearest to about: manifests, angeles, diagnostic, gmc, dossier, venomous, ionizing, homophobia,
# Nearest to two: samaria, capybaras, fruits, paddle, christof, childhood, islamic, topless,
# Nearest to often: bullock, macleod, branko, sleeps, graphene, deltas, yachts, randomization,
# Nearest to UNK: marcel, t, seize, cancellation, installer, sperry, belisarius, fantastic,
# Nearest to i: dermot, ligase, cygni, egyptologist, solely, invasions, cosine, stuart,
# Nearest to will: roadside, mirror, folds, archbishopric, mumps, neq, corrupted, regarding,
# Nearest to by: mannerisms, mcenroe, concubinage, curd, bornholm, interplay, cos, neh,
# Nearest to to: talkative, iommi, wapping, poe, honour, sidewise, orr, autumnal,
# Nearest to such: didache, sutton, toland, lace, gregor, paged, lifeboat, cmu,
# Nearest to are: ulysses, prattica, vaughan, philosophiae, whales, unrecognized, bodybuilding, astrologers,
# Nearest to so: ceo, dominating, paasikivi, corso, fest, hobbies, wields, rebuke,
# Nearest to b: mile, herbivore, economist, apache, psychotropic, membrane, avogadro, ertegun,
# Nearest to s: indexing, mothersbaugh, projections, lutheranism, saumur, receptors, tentative, sanders,
# Nearest to united: stimulated, titian, programmable, antonia, parthian, condita, flammable, ocs,
# Nearest to which: segregation, payne, clouded, audita, gaulish, cabinets, potawatomi, alsace,
# Nearest to no: taxable, caracalla, shires, kagoshima, barium, friend, deterred, insoluble,
# Average loss at step 2000: 4.370175
# Average loss at step 4000: 3.866574
# Average loss at step 6000: 3.792244
# Average loss at step 8000: 3.687914
# Average loss at step 10000: 3.620225
# Nearest to about: venomous, angeles, manifests, gmc, semiconductors, roof, diagnostic, interventionism,
# Nearest to two: four, three, five, six, seven, eight, zero, one,
# Nearest to often: who, sometimes, also, cyaxares, uma, bullock, pulitzer, they,
# Nearest to UNK: vied, hays, m, campaign, prosthetics, blackwood, film, tamerlane,
# Nearest to i: we, dermot, ligase, you, shortages, lia, invasions, consideration,
# Nearest to will: would, roadside, mirror, orr, realizing, but, regarding, stocks,
# Nearest to by: was, pioneers, with, on, be, been, cummings, bhaskara,
# Nearest to to: not, would, falsified, talkative, israelites, knowles, sidewise, vladivostok,
# Nearest to such: well, known, runnymede, contemplates, microchips, didache, torr, large,
# Nearest to are: were, is, was, have, defoe, be, injected, vienne,
# Nearest to so: cs, synthetically, commonly, reynolds, pronounces, wields, ceo, dominating,
# Nearest to b: d, herbivore, psychotropic, mile, membrane, avogadro, adolph, jigs,
# Nearest to s: his, and, shema, wf, arte, devoured, karen, stoichiometric,
# Nearest to united: stimulated, sacramental, parthian, cahill, adr, clicking, flagellates, antonia,
# Nearest to which: that, it, this, who, also, digests, novelist, what,
# Nearest to no: mentored, embed, secundus, deterred, matejko, rochelle, shires, tales,
# Average loss at step 12000: 3.602783
# Average loss at step 14000: 3.575522
# Average loss at step 16000: 3.405641
# Average loss at step 18000: 3.455987
# Average loss at step 20000: 3.542093
# Nearest to about: manifests, diagnostic, semiconductors, venomous, interventionism, signalled, relic, grouped,
# Nearest to two: three, five, four, six, eight, one, seven, nine,
# Nearest to often: sometimes, also, usually, widely, who, there, now, cyaxares,
# Nearest to UNK: w, l, cambridge, beaten, calamities, clinched, gdp, infective,
# Nearest to i: we, ii, schl, organ, shortages, you, marvels, lia,
# Nearest to will: would, should, may, can, to, could, roadside, orr,
# Nearest to by: into, be, been, was, with, were, pioneers, vfr,
# Nearest to to: must, would, not, will, can, may, sidewise, gelre,
# Nearest to such: well, known, other, contemplates, runnymede, abode, queue, schuman,
# Nearest to are: were, is, have, was, molars, applause, tribes, these,
# Nearest to so: synthetically, reynolds, commonly, dominating, allele, wields, ceo, pronounces,
# Nearest to b: d, unifies, herbivore, neman, psc, psychotropic, mannheim, acres,
# Nearest to s: damian, arte, acorns, lutheranism, ruddy, karen, esperantists, approximations,
# Nearest to united: stimulated, sacramental, categorised, parthian, adr, flagellates, clicking, cahill,
# Nearest to which: this, that, also, who, but, it, these, there,
# Nearest to no: matejko, scar, soybeans, mentored, tales, shor, deterred, a,
# Average loss at step 22000: 3.500235
# Average loss at step 24000: 3.491734
# Average loss at step 26000: 3.485805
# Average loss at step 28000: 3.480027
# Average loss at step 30000: 3.501105
# Nearest to about: eyes, that, venomous, semiconductors, between, homophobia, diagnostic, manifests,
# Nearest to two: three, four, five, six, one, seven, eight, nine,
# Nearest to often: sometimes, usually, also, widely, generally, now, still, frequently,
# Nearest to UNK: h, julien, hays, specialised, arrive, m, http, putative,
# Nearest to i: we, ii, you, schl, devoured, organ, cryptographic, shortages,
# Nearest to will: would, can, should, may, could, must, might, to,
# Nearest to by: with, in, under, were, was, bhaskara, lla, aldehydes,
# Nearest to to: would, can, will, must, wheelchair, malls, through, may,
# Nearest to such: well, these, other, known, many, runnymede, some, asymptotes,
# Nearest to are: were, have, is, these, clauses, include, professorship, be,
# Nearest to so: synthetically, if, commonly, allele, dominating, kwashiorkor, stanshall, reynolds,
# Nearest to b: d, apache, neman, psc, exeter, psychotropic, herbivore, cyclic,
# Nearest to s: his, shema, karen, ssl, signer, footballers, cereals, odorless,
# Nearest to united: stimulated, categorised, flagellates, parthian, cahill, past, humility, clicking,
# Nearest to which: this, that, also, who, these, but, it, what,
# Nearest to no: scar, matejko, soybeans, a, mentored, pleads, deterred, tales,
# Average loss at step 32000: 3.499130
# Average loss at step 34000: 3.494743
# Average loss at step 36000: 3.457895
# Average loss at step 38000: 3.296795
# Average loss at step 40000: 3.428202
# Nearest to about: manifests, semiconductors, definite, eyes, on, everyday, fairtrade, tough,
# Nearest to two: three, six, four, five, seven, eight, one, nine,
# Nearest to often: usually, sometimes, generally, also, widely, still, who, frequently,
# Nearest to UNK: b, decius, d, transboundary, asheville, c, yonkers, macphail,
# Nearest to i: we, ii, you, they, t, schl, he, cabinda,
# Nearest to will: would, can, could, should, may, must, might, cannot,
# Nearest to by: with, pioneers, was, were, when, as, islet, while,
# Nearest to to: must, sulpicius, hallucination, klansmen, sidewise, will, would, gamemaster,
# Nearest to such: well, these, known, asymptotes, including, runnymede, viral, certain,
# Nearest to are: were, have, is, these, include, shenandoah, but, sdi,
# Nearest to so: if, synthetically, reparations, know, allele, dominating, it, wields,
# Nearest to b: d, c, UNK, orfeo, displaying, herbivore, cyclic, pleads,
# Nearest to s: his, dhea, carson, subspecies, rnzaf, doggy, islami, affectionately,
# Nearest to united: titian, stimulated, flagellates, humility, clicking, parthian, categorised, past,
# Nearest to which: that, this, also, who, these, it, actually, what,
# Nearest to no: scar, backlit, matejko, any, mentored, tsunamis, deterred, a,
# Average loss at step 42000: 3.437176
# Average loss at step 44000: 3.456396
# Average loss at step 46000: 3.451774
# Average loss at step 48000: 3.348848
# Average loss at step 50000: 3.382538
# Nearest to about: definite, eyes, kos, venomous, assures, tley, scouting, everyday,
# Nearest to two: three, four, one, six, eight, five, seven, nine,
# Nearest to often: usually, sometimes, generally, also, now, commonly, frequently, widely,
# Nearest to UNK: weed, hindering, vehement, khan, web, bbs, www, julien,
# Nearest to i: we, ii, you, g, t, suffices, lia, cabinda,
# Nearest to will: would, can, could, may, should, must, might, shall,
# Nearest to by: was, with, regenerate, dine, under, through, islet, into,
# Nearest to to: must, sulpicius, may, sidewise, can, would, could, malls,
# Nearest to such: well, these, known, many, runnymede, viral, asymptotes, including,
# Nearest to are: were, is, have, these, was, be, professorship, helene,
# Nearest to so: if, then, testimonies, synthetically, allele, ls, ll, she,
# Nearest to b: d, c, apache, displaying, orfeo, bowler, five, cyclic,
# Nearest to s: ruddy, footballers, presided, sub, internalism, subspecies, but, and,
# Nearest to united: stimulated, clicking, titian, parthian, flagellates, dukedom, sunset, humility,
# Nearest to which: that, this, also, who, often, what, where, now,
# Nearest to no: any, scar, backlit, a, mentored, little, jacinto, centimetres,
# Average loss at step 52000: 3.438169
# Average loss at step 54000: 3.425456
# Average loss at step 56000: 3.439886
# Average loss at step 58000: 3.396830
# Average loss at step 60000: 3.393505
# Nearest to about: over, definite, nearly, telephones, testified, unbeaten, fairtrade, tley,
# Nearest to two: three, four, six, five, eight, one, seven, nine,
# Nearest to often: usually, sometimes, generally, commonly, now, frequently, widely, also,
# Nearest to UNK: mammuthus, www, adjectival, http, resource, csv, saar, behistun,
# Nearest to i: we, ii, you, g, t, suffices, kenneth, lia,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to by: with, through, under, after, boosted, cezanne, wolves, bhaskara,
# Nearest to to: stipulation, flurry, sulpicius, would, glaciations, wheelchair, malls, falsified,
# Nearest to such: well, these, known, many, camped, viral, asymptotes, few,
# Nearest to are: were, is, have, include, these, including, arunachal, molars,
# Nearest to so: allele, if, synthetically, fact, ls, talleyrand, testimonies, reparations,
# Nearest to b: d, c, p, n, m, r, alkanes, z,
# Nearest to s: wards, footballers, damian, presided, braxton, his, doggy, stoichiometric,
# Nearest to united: clicking, titian, stimulated, same, past, humility, sunset, hongkong,
# Nearest to which: that, this, what, who, these, however, but, also,
# Nearest to no: little, any, scar, centimetres, jacinto, backlit, tsunamis, breeding,
# Average loss at step 62000: 3.242496
# Average loss at step 64000: 3.256430
# Average loss at step 66000: 3.400562
# Average loss at step 68000: 3.394828
# Average loss at step 70000: 3.360248
# Nearest to about: over, telephones, definite, regarding, assures, on, pooh, externalism,
# Nearest to two: three, six, four, five, seven, one, eight, nine,
# Nearest to often: sometimes, usually, generally, commonly, frequently, now, widely, also,
# Nearest to UNK: mythical, marcel, rocked, deterrence, yin, kabbalists, monaghan, sequences,
# Nearest to i: we, ii, you, g, kenneth, hydrated, papacy, lia,
# Nearest to will: would, could, may, can, should, must, might, cannot,
# Nearest to by: using, through, was, islet, be, fined, cummings, is,
# Nearest to to: can, must, sulpicius, cannot, will, would, for, stipulation,
# Nearest to such: these, well, known, many, asymptotes, viral, camped, certain,
# Nearest to are: were, is, include, have, these, although, be, including,
# Nearest to so: allele, ls, if, thus, synthetically, dense, corso, testimonies,
# Nearest to b: d, z, p, c, r, f, orfeo, bowler,
# Nearest to s: footballers, ruddy, stoichiometric, subspecies, splendor, whose, the, karen,
# Nearest to united: titian, clicking, sunset, humility, sacramental, same, opcode, stimulated,
# Nearest to which: that, this, also, but, what, lomond, however, often,
# Nearest to no: little, centimetres, breeding, scar, any, backlit, cassian, mentored,
# Average loss at step 72000: 3.375053
# Average loss at step 74000: 3.348238
# Average loss at step 76000: 3.320938
# Average loss at step 78000: 3.355088
# Average loss at step 80000: 3.377729
# Nearest to about: over, telephones, testified, regarding, definite, unbeaten, nearly, dimensional,
# Nearest to two: three, six, four, seven, five, eight, one, zero,
# Nearest to often: usually, sometimes, generally, commonly, frequently, now, widely, still,
# Nearest to UNK: kreutzmann, champlain, e, augustine, maria, stuart, http, khan,
# Nearest to i: ii, you, we, g, medallist, hydrated, cabinda, kenneth,
# Nearest to will: would, could, should, can, may, must, might, cannot,
# Nearest to by: through, cummings, pioneers, bhaskara, using, hanja, eos, under,
# Nearest to to: will, sidewise, must, towards, sulpicius, earned, cannot, malls,
# Nearest to such: these, well, known, follows, regarded, certain, including, schuman,
# Nearest to are: were, is, have, include, although, be, sdi, these,
# Nearest to so: ls, if, allele, testimonies, dense, fact, synthetically, berle,
# Nearest to b: d, c, p, z, evaporates, bowler, r, displaying,
# Nearest to s: presided, isbn, eventual, braxton, whose, footballers, secures, heiner,
# Nearest to united: titian, humility, same, flagellates, clicking, opcode, sunset, hongkong,
# Nearest to which: that, this, typically, what, also, lomond, often, usually,
# Nearest to no: little, centimetres, mentored, any, backlit, breeding, cassian, fewer,
# Average loss at step 82000: 3.407068
# Average loss at step 84000: 3.406665
# Average loss at step 86000: 3.392941
# Average loss at step 88000: 3.355315
# Average loss at step 90000: 3.369800
# Nearest to about: regarding, over, tley, definite, discusses, telephones, kos, rounding,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to often: usually, sometimes, commonly, generally, frequently, now, widely, also,
# Nearest to UNK: http, sih, tri, l, abdal, pausanias, maria, bjarne,
# Nearest to i: you, we, ii, g, devoured, iv, medallist, antipodes,
# Nearest to will: would, could, can, should, may, must, might, cannot,
# Nearest to by: through, with, from, under, while, dili, for, when,
# Nearest to to: gamemaster, malls, towards, sidewise, effendi, klansmen, transmits, sulpicius,
# Nearest to such: well, known, these, camped, follows, certain, basica, regarded,
# Nearest to are: were, is, include, have, these, although, emil, sdi,
# Nearest to so: thus, if, testimonies, ls, too, before, dense, papyrus,
# Nearest to b: d, c, r, z, p, n, displaying, f,
# Nearest to s: presided, wards, isbn, his, ruddy, intimidation, plutocracy, lawrence,
# Nearest to united: finnish, humility, titian, confederate, sectional, sunset, same, sacramental,
# Nearest to which: that, this, what, also, typically, usually, lomond, actually,
# Nearest to no: little, any, backlit, centimetres, cassian, fewer, merely, nothing,
# Average loss at step 92000: 3.398889
# Average loss at step 94000: 3.255390
# Average loss at step 96000: 3.357610
# Average loss at step 98000: 3.241991
# Average loss at step 100000: 3.354646
# Nearest to about: over, discusses, regarding, telephones, unbeaten, tley, on, aylwin,
# Nearest to two: three, four, six, five, eight, seven, one, nine,
# Nearest to often: usually, sometimes, commonly, generally, frequently, now, typically, widely,
# Nearest to UNK: drunk, pbs, rubinstein, trimmed, wo, derives, statuette, eyelashes,
# Nearest to i: ii, we, you, g, lia, hydrated, iv, oh,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to by: through, when, using, fined, bhaskara, with, during, dili,
# Nearest to to: will, sulpicius, must, towards, sidewise, could, should, can,
# Nearest to such: well, known, these, follows, camped, queue, many, regarded,
# Nearest to are: were, have, these, be, those, include, is, although,
# Nearest to so: thus, too, testimonies, ls, something, then, swam, papyrus,
# Nearest to b: d, c, invokes, displaying, donato, twigs, sacking, exeter,
# Nearest to s: whose, his, the, ruddy, assessing, loyalties, lawrence, unopened,
# Nearest to united: finnish, humility, confederate, titian, sunset, principal, irreducibly, sectional,
# Nearest to which: that, this, usually, what, also, typically, lomond, actually,
# Nearest to no: any, little, backlit, cassian, petals, jacinto, scar, marathas,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
